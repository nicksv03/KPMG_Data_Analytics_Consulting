# %%
import pandas as pd
import numpy as np

# %%
import os
path = r'/Users/nikhil/Library/CloudStorage/GoogleDrive-dcbs17nikhilverma@gmail.com/My Drive/Github/KPMG_Data_Analytics_Consulting'
os.chdir(path.replace('\\', '/'))

# %%
# load data
cust_add = pd.read_csv(path +r'/dataset/customer_address.csv', skiprows=1)
cust_dem = pd.read_csv(path +r'/dataset/customer_demographic.csv', skiprows=1)
new_cust = pd.read_csv(path +r'/dataset/new_customer_list.csv', skiprows=1)
trx = pd.read_csv(path +r'/dataset/transactions.csv', skiprows=1)

# %% [markdown]
# ### Customer Address

# %%
cust_add.tail(10).T
# Out:
#                              3986             3987               3988  \
# customer_id                  3991             3992               3993
# address             24 Scott Pass  8 Randy Parkway  681 Elmside Place
# postcode                     4300             2209               3750
# state                         QLD              NSW                VIC
# country                 Australia        Australia          Australia
# property_valuation              5               11                  6
#
#                                       3989           3990                3991  \
# customer_id                           3994           3995                3996
# address             2918 Summer Ridge Hill  613 Erie Lane  0 Transport Center
# postcode                              3030           2088                3977
# state                                  VIC            NSW                 VIC
# country                          Australia      Australia           Australia
# ...

# %% [markdown]
# There are 4003 customer id's in the address database while there are 4000 customer id's in the customer demographic database. This means that there are 3 customers who do not have an address. We will remove these 3 customers from the customer database.

# %%
cust_add = cust_add.drop(cust_add.tail(3).index)

# %%
cust_add['customer_id'].min(), cust_add['customer_id'].max()
# Out:
# (1, 4000)

# %%
# missing values check
cust_add.isnull().sum()
# no missing values
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
# duplicate check
cust_add['customer_id'].duplicated().sum()
# no duplicate customer_id
# Out:
# 0

# %% [markdown]
# ### Customer Demographics

# %%
cust_dem.tail(10).T
# Out:
#                                                       3990  \
# customer_id                                           3991
# first_name                                           Rolph
# last_name                                         Sweetnam
# gender                                                Male
# past_3_years_bike_related_purchases                     61
# DOB                                    1985-08-06 00:00:00
# job_title                            Chief Design Engineer
# job_industry_category                        Manufacturing
# wealth_segment                               Mass Customer
# deceased_indicator                                       N
# default                                                 "'
# owns_car                                               Yes
# tenure                                                13.0
#
#                                                                                   3991  \
# ...

# %%
cust_dem['customer_id'].min(), cust_dem['customer_id'].max()
# Out:
# (1, 4000)

# %%
# Missing Values Check
cust_dem.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
# Duplicate Values Check
cust_dem['customer_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### New Customers

# %%
new_cust.head(10)
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
# 5      Druci    Brandli  Female                                   39
# 6   Rutledge      Hallt    Male                                   23
# 7     Nancie       Vian  Female                                   74
# 8       Duff  Karlowicz    Male                                   50
# 9    Barthel     Docket    Male                                   72
#
#                    DOB                     job_title job_industry_category  \
# 0           1957-07-12               General Manager         Manufacturing
# ...

# %%
# Missing Values Check
new_cust.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
# Duplicate Values Check
new_cust.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Transactions

# %%
trx.head(10).T
# Out:
#                                            0                    1  \
# transaction_id                             1                    2
# product_id                                 2                    3
# customer_id                             2950                 3120
# transaction_date         2017-02-25 00:00:00  2017-05-21 00:00:00
# online_order                           False                 True
# order_status                        Approved             Approved
# brand                                  Solex        Trek Bicycles
# product_line                        Standard             Standard
# product_class                         medium               medium
# product_size                          medium                large
# list_price                             71.49              2091.47
# standard_cost                          53.62               388.92
# product_first_sold_date              41245.0              41701.0
#
# ...

# %%
# Missing Values Check
trx.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
# Duplicate Values Check
trx['transaction_id'].duplicated().sum()
# Out:
# 0
