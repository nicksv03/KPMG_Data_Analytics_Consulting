# %%
import pandas as pd
import numpy as np

# %%
import os
path = r'/Users/nikhil/Library/CloudStorage/GoogleDrive-dcbs17nikhilverma@gmail.com/My Drive/Github/KPMG_Data_Analytics_Consulting'
os.chdir(path.replace('\\', '/'))

# %%
# load data
cust_add = pd.read_csv(path +r'/dataset/customer_address.csv')
cust_dem = pd.read_csv(path +r'/dataset/customer_demographic.csv')
new_cust = pd.read_csv(path +r'/dataset/new_customer_list.csv')
trx = pd.read_csv(path +r'/dataset/transactions.csv')

# %%
cust_add.head(10).T
# Out:
#                                                                      0  \
# Note: The data and information in this document...         customer_id
# Unnamed: 1                                                     address
# Unnamed: 2                                                    postcode
# Unnamed: 3                                                       state
# Unnamed: 4                                                     country
# Unnamed: 5                                          property_valuation
#
#                                                                      1  \
# Note: The data and information in this document...                   1
# Unnamed: 1                                          060 Morning Avenue
# Unnamed: 2                                                        2016
# Unnamed: 3                                             New South Wales
# Unnamed: 4                                                   Australia
# ...

# %%
cust_add.columns = cust_add.columns[0:]
